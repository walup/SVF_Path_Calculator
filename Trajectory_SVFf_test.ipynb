# %%
from TrajectorySVFf import TrajectorySVFf
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
points = np.array([[19.437181, -99.145089], [19.436203, -99.141166], [19.435948, -99.139540], [19.435653, -99.137625], [19.435454, -99.136302]])

# %%
trajectorySVF = TrajectorySVFf(points)

# %%
key = "AIzaSyCJQcHD07xfjXpdqVSl2T4-ujwt3AmFVMQ"
trajectorySVF.getSVFForTrajectory("Panoramic_Google", key)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:153: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:212.)
#   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
plt.figure()
plt.plot([1,2,3,4,5], trajectorySVF.svfArray, marker = "o", linestyle = "none")
plt.xlabel("Punto de trajectoria")
plt.ylabel("SVFf")
# Out:
# Text(0, 0.5, 'SVFf')

# %%
trajectorySVF.svfArray
# Out:
# [0.04477, 0.410306, 0.314693, 0.000106, 0.0]

# %%
fig, ax = plt.subplots(5,1, figsize = (15,12))

ax[0].imshow(Image.open("Panoramic_Google/panoramica_0.jpg"))
ax[1].imshow(Image.open("Panoramic_Google/panoramica_1.jpg"))
ax[2].imshow(Image.open("Panoramic_Google/panoramica_2.jpg"))
ax[3].imshow(Image.open("Panoramic_Google/panoramica_3.jpg"))
ax[4].imshow(Image.open("Panoramic_Google/panoramica_4.jpg"))
